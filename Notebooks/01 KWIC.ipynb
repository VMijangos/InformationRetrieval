# %% [markdown]
# # Key Word in Context
#
# Las Key Word in Context (KWIC) o concoordancias recuperan un patrón dentro de un documento o una colección de documentos. Las KWIC son útiles para ubicar la información en su contexto, pero también nos pueden indicar en qué documentos se encuentran las palabras.
#
# ### Corpus
#
# El corpus o colección con el que trabajaremos es el corpus CESS-ESP, un corpus de documentos parlamentales en español.

# %%
from nltk.corpus import cess_esp

corpus = ' '.join(cess_esp.words())

print(corpus[:100])
# Out:
# El grupo estatal Electricité_de_France -Fpa- EDF -Fpt- anunció hoy , jueves , la compra del 51_por_c

# %% [markdown]
# ### Recuperación de KWIC
#
# Para obtener las KWIC necesitamos un método que escanee el texto y encuentre los patrones de búsqueda (keywords o palabras clave) dentro del documento.
#
# En este caso, se ubica la posición de la palabra y se recupera el contexto, en términos de caracteres.

# %%
def keywords_in_context(text, keyword, context_length=15):
    """ 
    Returns the relevant context around keywords in a larger text.
    
    Arguments
    ----------
    text : str
        Texto en donde deseamos encontrar las keywords
    keyword : list of str
        La keyword o palabra clave que deseamos encontrar.
    context_length : int
        Máximo número de caracteres que aparecerán a la derecha y la izquierda de la keyword.
        
    Returns
    -------
    Concoordancias en donde aparece la palabra clave en el texto.
    """
    #Pasa el texto a minúsculas
    text = text.lower()
    #Lista de índices posicionales
    indices_lst = []    
    #Encontrar posición de inicio de keyword en texto
    start = text.find(keyword)
    while not start == -1:
        #Añade el índice a la lista
        indices_lst.append(start)
        #Encontrar siguiente posición
        start = text.find(keyword, start+len(keyword))
    
    for idx in indices_lst:
        #Guarda el inicio de keyword
        start = idx
        #guarda el final de keyword
        end = idx+len(keyword)
        #Elemento previo 
        prev = text[0:start]
        #Elemento siguiente
        next = text[end:-1]
        
        #Revisa el contexto anterior
        if len(prev) < context_length:
            #Si no hay elementos antes
            #Recupera sólo la keyword
            prev_context = start-len(prev)
        else:
            #Si hay elementos antes
            #Recupera el contexto anterior
            prev_context = start-context_length
        #Revisa el contexto siguiente
        if len(next) < context_length:
            #Si no hay elementos después
            #Recupera sólo la keyword
            next_context = end+len(next)
        else:
            #Si hay elementos después
            #Recupera el contexto siguiente
            next_context = end+context_length
        
        #Regresa la kwyc
        yield text[prev_context:next_context]

# %% [markdown]
# Podemos aplicar a un caso específico.

# %%
#Keyword
keyword = 'democracia'

#Imprime las concoordancias
for kwic in keywords_in_context(corpus,keyword,context_length=50):
    print(kwic)
# Out:
# del partido en madrid desde la instauración de la democracia . insuficiente fue el crecimiento del psoe en la
# jor resultado del partido en madrid en 25 años de democracia " , dijo a efe el presidente del pp en la región
# n educativa , materia esencial para consolidar la democracia y lograr el desarrollo social . vicumbre -fpa- vi
# iña_del_mar , dedicada a la " gobernabilidad y la democracia " , reafirmó el compromiso con el sistema democrá
# ntales como " marco de la gobernabilidad para una democracia eficiente y participativa " . se puso como objeti
# cipativa " . se puso como objetivo consolidar las democracias y fortalecer las instituciones y la cultura demo
# ar las bases socioeconómicas para posibilitar una democracia integral , así_como asumir las oportunidades que
#  1997 -fpt- dedicado a " los valores éticos de la democracia " , el texto final condenó expresamente por prime
# ad española " ha dado un importante respaldo a la democracia , al estado_de_derecho y al gobierno de josé_marí
# anciones contra fiyi por abandonar la senda de la democracia . el primer ministro israelí , ehud_barak , llegó
# ró la " pedagógica " medida como un triunfo de la democracia venezolana . desde entonces *0* entró en silencio
# persona " de quien *0* piensa aceptar " clases de democracia " . ambos políticos se acusaron mutuamente de pon
# haciendo promoción de los valores humanos y de la democracia ... . estados_unidos tiene que ser fuerte para po
# los franceses " , indicó alain_madelin , líder de democracia_liberal . bajo el titular " jospin_,obligado_a_ba
# se país , con_el_fin_de ayudarle a fomentar " una democracia estable , abierta y pluralista " en una " economí
#  resolverse a nivel regional . bell afirmó que la democracia de colombia " es hoy una democracia amenazada " ,
# afirmó que la democracia de colombia " es hoy una democracia amenazada " , por lo que *0* aseguró que la lucha
# s internos " . " el proceso de paz se apoya en la democracia , integridad territorial y derechos_humanos " , d
#  que " reafirmó " su " compromiso con la paz , la democracia , la tolerancia y la pluralidad de la sociedad va
#  soberanía a los españoles y que desembocó en una democracia saludable y estable como la que *0* tenemos en es
# raciones históricas : pasar de una dictadura a la democracia , pasar de un estado centralizado a otro muy desc
# o dos sectores dentro del psoe " , el de la socialdemocracia , en el que *0* se incluyó , que " cuenta con cer
# erio coincidieron en que el fortalecimiento de la democracia y la consolidación de las instituciones internas
# mo instrumento que la oea tiene para preservar la democracia representativa en el continente . ramacciotti afi
# uar con esa política " *0* caminaríamos hacia una democracia autoritaria " . alemania y estados_unidos no lleg
# ituación de chechenia y la posición respecto_a la democracia . " *0* tienen interés en una rusia fuerte , pero
# bló con la secretaria de la liga_nacional_para_la_democracia , aung_san_suu_kyi , quien insistió en " la grave
# do continuó hoy su campaña por el " rescate de la democracia " con un multitudinario mitin en la ciudad de cañ
# contra fiyi para lograr el restablecimiento de la democracia constitucional en ese país . la decisión surge en
# ejercer una presión que implique el regreso de la democracia a fiyi " , dijo el presidente de la ctu , ross_wi
# ater , como *0* no sea el compromiso común con la democracia y esa dignidad en el comportamiento público de qu
# mucho más difícil la posterior construcción de la democracia . por_supuesto éste no es el caso actual , pero l
# s , pero muchas de ellas no temen que se acabe la democracia sino que se acabe su poder . como escribió gilber
# y en su tiempo , ahora también a nosotros nuestra democracia nos parece tan firme y tan segura y , sobre_todo
# i se abusa de la sátira . todo indica que nuestra democracia aguanta la crisis , y la inestabilidad política e

# %% [markdown]
# ### KWIC en colecciones
#
# Cuando buscamos una palabra clave en una colección, además de recuperar la concoordancia es común recuperar el documento en el que ésta aparece. En este caso pocemos aprovechar el método que hemos definido anteriormente para hacer búsquedas de kwic en colecciones.
#
# En primer lugar cargamos el directorio con la colección de documentos:

# %%
from glob import glob

#Directorio donde se encuentras los documentos
directory = 'wikipedia/'

#Guarda el nombre del documento
#y su texto
texts = {}
for filename in glob(directory+'*'):
    #Lee el texto y lo pasa a minúscula
    text = open(filename,'r').read().lower()
    texts[filename] = text

# %%
def kwic_in_collection(keyword, collection, context_length=15):
    """
    Función para recuperar kwic en una colección de documentos.
    
    Arguments
    ----------
    keyword : str
        Palabra clave que recuperaremos en la colección
    collection : dict
        Dictionario de {nombre del documento : texto} que contiene la colección.
    context_length : int
        Número máximo de caracteres en el contexto
        
    Returns
    -------
    Concoordancias en donde aparece la palabra clave y el nombre del texto en que aparece de la colección.
    """
    for fname, text in collection.items():
        for kwic in keywords_in_context(text, keyword, context_length=context_length):
            yield "{} : {}".format(kwic, fname[10:])

# %% [markdown]
# Podemos ahora aplicar el método a una colección.

# %%
#Keyword
keyword = 'bacteria'

for c in kwic_in_collection(keyword, texts):
    print(c)
# Out:
# a de una enterobacteria que se encuent : ech (1).txt
# .
# esta y otras bacterias son necesaria : ech (1).txt
# s ++--.
# es una bacteria utilizada frec : ech (1).txt
# s decir, si la bacteria no adquiere el : ech (1).txt
# virulentos, la bacteria actúa como un  : ech (1).txt
# s acerca de la bacteria escherichia co : ech (3).txt
# e trata de una bacteria con diversas v : ech (3).txt
# otras cepas la bacteria que ha golpead : ech (3).txt
# uién afecta la bacteria?
# la bacteria p : ech (3).txt
# a bacteria?
# la bacteria puede afectar  : ech (3).txt
# l caso de esta bacteria es muy baja, l : ech (3).txt
#  ingeridos.
# la bacteria no es resisten : ech (3).txt
# que produce la bacteria», como dice la : ech (3).txt
# lmonella es la bacteria que produce la : salmonella (3).txt
# sionada por la bacteria de la salmonel : salmonella (3).txt
# una enfermedad bacterial que afecta el : salmonella (3).txt
# normalmente la bacteria de la salmonel : salmonella (3).txt
# taminan con la bacteria al consumir ag : salmonella (3).txt
# nfectan con la bacteria de la salmonel : salmonella (3).txt
# agiarse con la bacteria de la salmonel : salmonella (3).txt
# sociado con la bacteria de la salmonel : salmonella (3).txt
# entes tipos de bacterias de la salmone : salmonella (3).txt
#  en ee.uu. las bacterias más comunes s : salmonella (3).txt
# amaño como son bacterias, restos celul : celula (2).txt
# en ser virus o bacterias. también son  : celula (2).txt
# ífica
# dominio:	bacteria
# filo:	proteoba : buchnera (1).txt
# ia
# filo:	proteobacteria
# clase:	gammapr : buchnera (1).txt
# se:	gammaproteobacteria
# orden:	enterob : buchnera (1).txt
# a
# orden:	enterobacteriales
# familia:	en : buchnera (1).txt
# familia:	enterobacteriaceae
# género:	bu : buchnera (1).txt
# a es una proteobacteria de la famlia e : buchnera (1).txt
# a famlia enterobacteriaceae. es un end : buchnera (1).txt
# modernos enterobacteriaceae tales como : buchnera (1).txt
# arientes enterobacteriaceae tales como : buchnera (1).txt
# mayoría de las bacterias gram-negativa : buchnera (1).txt
# ar a 5,6 × 106 bacterias. buchnera ha  : buchnera (1).txt
# lgas y algunas bacterias.
#
# —	quimiosín : celula (3).txt
# alizan algunas bacterias.
#
# b)	nutrició : celula (3).txt
# mayoría de las bacterias : celula (3).txt
# causada por la bacteria salmonella. la : salmonella (2).txt
# salmonella. la bacteria vive en el int : salmonella (2).txt
# nadas con esta bacteria. las mascotas  : salmonella (2).txt
# ectados con la bacteria como perros y  : salmonella (2).txt
# un conjunto de bacterias de interes en : pylori (3).txt
#  pylori
# es una bacteria gram negativa, : pylori (3).txt
# to actual esta bacteria sólo se ha enc : pylori (3).txt
# genoma de la bacteria buchnera aphid : buchnera (2).txt
# ra cedri' y la bacteria 'buchnera aphi : buchnera (2).txt
# uministra a la bacteria un ambiente es : buchnera (2).txt
# , a su vez, la bacteria le suministra  : buchnera (2).txt
# ter pylori una bacteria peligrosa
#
# la  : pylori (1).txt
#  peligrosa
#
# la bacteria helicobacter p : pylori (1).txt
# estómago, esta bacteria es capaz de ge : pylori (1).txt
# crónicas.
# las bacterias son la princi : pylori (1).txt
# ylori como una bacteria que tiene form : pylori (1).txt
# ctada por esta bacteria, aunque en paí : pylori (1).txt
# ecialista.
# "la bacteria produce una se : pylori (1).txt
# ente ácido, la bacteria produce excesi : pylori (1).txt
# protege a esta bacteria del ácido clor : pylori (1).txt
# ntífica
# reino:	bacteria
# filo:	proteoba : salmonella (1).txt
# ia
# filo:	proteobacteria
# clase:	gammapr : salmonella (1).txt
# se:	gammaproteobacteria
# orden:	enterob : salmonella (1).txt
# a
# orden:	enterobacteriales
# familia:	en : salmonella (1).txt
# familia:	enterobacteriaceae
# género:	sa : salmonella (1).txt
# s un género de bacterias que pertenece : salmonella (1).txt
#  familia enterobacteriaceae, formado p : salmonella (1).txt
# i esporas. son bacterias móviles que p : salmonella (1).txt
# o de las enterobacterias.
# para la bact : salmonella (1).txt
# n descubrió la bacteria en 1885, aislá : salmonella (1).txt
# 6
# al ser estas bacterias muy poco resi : salmonella (1).txt
# al, y la flora bacteriana normal. los  : salmonella (1).txt
# casionadas por bacterias del género sa : salmonella (1).txt
# iento de otras bacterias patógenas y d : salmonella (1).txt
# número de esta bacteria y se observa f : salmonella (1).txt
# gual que otras bacteria gram negativas : salmonella (1).txt
# elular y de la bacteria. se ha observa : salmonella (1).txt
# os, dejando la bacteria virtualmente d : salmonella (1).txt
# acelular de la bacteria.8 9
# profilaxis : salmonella (1).txt
# ella es una enobacteria se contamina e : salmonella (1).txt
# o, destruir la bacteria en los aliment : salmonella (1).txt
# l). se deben a bacterias q u epenetran : salmonella (1).txt
# e las diarreas bacterianas se realiza  : salmonella (1).txt
#  de la diarrea bacteriana depende de l : salmonella (1).txt
# e las diarreas bacterianas se realiza  : salmonella (1).txt
#  de la diarrea bacteriana depende de l : salmonella (1).txt
# n íntima de la bacteria al enterocito  : ech (2).txt
# s procariotas (bacterias) no tienen co : celula (5).txt
# egetal. en las bacterias, por otra par : celula (4).txt
# s células
#
# las bacterias, como muchos  : celula (4).txt
# rman.
#
# en las bacterias, que no posee : celula (4).txt
#  pero como las bacterias no cuentan má : celula (4).txt
# externa de las bacterias y la membrana : celula (4).txt
# a inclusión de bacterias en el interio : celula (4).txt
#  pylori es una bacteria que infecta el : pylori (2).txt
#  síntoma. esta bacteria vive exclusiva : pylori (2).txt
#  ácido. es una bacteria espiral (de es : pylori (2).txt
#  estomacal.
# la bacteria fue llamada in : pylori (2).txt
#  pylori es una bacteria gram negativa  : pylori (2).txt
# ma espiral, la bacteria "taladra" lite : pylori (2).txt
# mayor parte de bacterias digeridas). l : pylori (2).txt
# tar código]
# la bacteria ha sido aislad : pylori (2).txt
# ctada por esta bacteria. la proporción : pylori (2).txt
# descomposición bacteriana altamente co : sacarosa (1).txt
